# %%
"""
Load OBELiX train/test and Liverpool
Clean conductivity values (handle <1E-10, convert to log scale)
Filter Liverpool to room temp
Deduplicate Liverpool against OBELiX using Liion ID
Combine into your training pool (OBELiX train + new Liverpool entries)
Keep OBELiX test completely separate
Save everything clean
"""
